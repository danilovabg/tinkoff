# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('/home/anna/SF/data/KaggleV2-May-2016.csv')
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# 1         0           0        0             0      No
# 2         0           0        0             0      No
# 3         0           0        0             0      No
# 4         1           0        0             0      No

# %%
df.hist(figsize=(8,8));

# %% [markdown]
#     Каково соотношение людей, которые пропускают встречи, к тем, кто этого не делает?
#     Кто не появляется чаще — мужчины или женщины?

# %%
plt.figure(figsize=(8,4))
df['No-show'].hist()
plt.title('Соотношение людей, которые пропускают приемы, к тем, кто этого не делает');

# %%
df['No-show'].value_counts(True)
# Out:
# No     0.798067
# Yes    0.201933
# Name: No-show, dtype: float64

# %%
df[df['No-show']=='Yes']['Gender'].value_counts(True)
# Out:
# F    0.653882
# M    0.346118
# Name: Gender, dtype: float64

# %%
categorical_columns_names = ['Gender', 'Neighbourhood']
encoded_columns = pd.get_dummies(df, columns = categorical_columns_names)

# %%
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_81be6_row0_col0, #T_81be6_row1_col1, #T_81be6_row2_col2, #T_81be6_row3_col3, #T_81be6_row4_col4, #T_81be6_row5_col5, #T_81be6_row6_col6, #T_81be6_row7_col7, #T_81be6_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col2, #T_81be6_row0_col3, #T_81be6_row5_col7, #T_81be6_row7_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col4, #T_81be6_row1_col0, #T_81be6_row3_col7, #T_81be6_row8_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col6, #T_81be6_row1_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_81be6_row0_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_81be6_row1_col2, #T_81be6_row4_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_81be6_row1_col3, #T_81be6_row4_col7 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_81be6_row1_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_81be6_row1_col5, #T_81be6_row5_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_81be6_row1_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_81be6_row1_col8, #T_81be6_row2_col3, #T_81be6_row3_col2, #T_81be6_row3_col4, #T_81be6_row3_col5, #T_81be6_row4_col0, #T_81be6_row7_col0, #T_81be6_row8_col0, #T_81be6_row8_col1, #T_81be6_row8_col6, #T_81be6_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_81be6_row2_col0, #T_81be6_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_81be6_row2_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_81be6_row2_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_81be6_row2_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_81be6_row2_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_81be6_row2_col7, #T_81be6_row7_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_81be6_row2_col8, #T_81be6_row4_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_81be6_row3_col1, #T_81be6_row5_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_81be6_row3_col6, #T_81be6_row5_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_81be6_row3_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_81be6_row4_col2 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_81be6_row4_col5 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_81be6_row4_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_81be6_row4_col8 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_81be6_row5_col0, #T_81be6_row8_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_81be6_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_81be6_row5_col4 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_81be6_row5_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col7, #T_81be6_row7_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_81be6_row6_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_81be6_row7_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_81be6_row7_col2 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_81be6_row7_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_81be6_row7_col8 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_81be6_row8_col2 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_81be6_row8_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81be6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81be6_level0_col0" class="col_heading level0 col0" >PatientId</th>
#       <th id="T_81be6_level0_col1" class="col_heading level0 col1" >AppointmentID</th>
#       <th id="T_81be6_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_81be6_level0_col3" class="col_heading level0 col3" >Scholarship</th>
#       <th id="T_81be6_level0_col4" class="col_heading level0 col4" >Hipertension</th>
#       <th id="T_81be6_level0_col5" class="col_heading level0 col5" >Diabetes</th>
#       <th id="T_81be6_level0_col6" class="col_heading level0 col6" >Alcoholism</th>
#       <th id="T_81be6_level0_col7" class="col_heading level0 col7" >Handcap</th>
#       <th id="T_81be6_level0_col8" class="col_heading level0 col8" >SMS_received</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81be6_level0_row0" class="row_heading level0 row0" >PatientId</th>
#       <td id="T_81be6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_81be6_row0_col1" class="data row0 col1" >0.004039</td>
#       <td id="T_81be6_row0_col2" class="data row0 col2" >-0.004139</td>
#       <td id="T_81be6_row0_col3" class="data row0 col3" >-0.002880</td>
#       <td id="T_81be6_row0_col4" class="data row0 col4" >-0.006441</td>
#       <td id="T_81be6_row0_col5" class="data row0 col5" >0.001605</td>
#       <td id="T_81be6_row0_col6" class="data row0 col6" >0.011011</td>
#       <td id="T_81be6_row0_col7" class="data row0 col7" >-0.007916</td>
#       <td id="T_81be6_row0_col8" class="data row0 col8" >-0.009749</td>
#     </tr>
#     <tr>
#       <th id="T_81be6_level0_row1" class="row_heading level0 row1" >AppointmentID</th>
#       <td id="T_81be6_row1_col0" class="data row1 col0" >0.004039</td>
#       <td id="T_81be6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_81be6_row1_col2" class="data row1 col2" >-0.019126</td>
#       <td id="T_81be6_row1_col3" class="data row1 col3" >0.022615</td>
#       <td id="T_81be6_row1_col4" class="data row1 col4" >0.012752</td>
#       <td id="T_81be6_row1_col5" class="data row1 col5" >0.022628</td>
#       <td id="T_81be6_row1_col6" class="data row1 col6" >0.032944</td>
#       <td id="T_81be6_row1_col7" class="data row1 col7" >0.014106</td>
#       <td id="T_81be6_row1_col8" class="data row1 col8" >-0.256618</td>
#     </tr>
#     <tr>
#       <th id="T_81be6_level0_row2" class="row_heading level0 row2" >Age</th>
#       <td id="T_81be6_row2_col0" class="data row2 col0" >-0.004139</td>
#       <td id="T_81be6_row2_col1" class="data row2 col1" >-0.019126</td>
#       <td id="T_81be6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_81be6_row2_col3" class="data row2 col3" >-0.092457</td>
#       <td id="T_81be6_row2_col4" class="data row2 col4" >0.504586</td>
#       <td id="T_81be6_row2_col5" class="data row2 col5" >0.292391</td>
#       <td id="T_81be6_row2_col6" class="data row2 col6" >0.095811</td>
#       <td id="T_81be6_row2_col7" class="data row2 col7" >0.078033</td>
#       <td id="T_81be6_row2_col8" class="data row2 col8" >0.012643</td>
#     </tr>
#     <tr>
#       <th id="T_81be6_level0_row3" class="row_heading level0 row3" >Scholarship</th>
#       <td id="T_81be6_row3_col0" class="data row3 col0" >-0.002880</td>
#       <td id="T_81be6_row3_col1" class="data row3 col1" >0.022615</td>
#       <td id="T_81be6_row3_col2" class="data row3 col2" >-0.092457</td>
#       <td id="T_81be6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_81be6_row3_col4" class="data row3 col4" >-0.019729</td>
#       <td id="T_81be6_row3_col5" class="data row3 col5" >-0.024894</td>
#       <td id="T_81be6_row3_col6" class="data row3 col6" >0.035022</td>
#       <td id="T_81be6_row3_col7" class="data row3 col7" >-0.008586</td>
#       <td id="T_81be6_row3_col8" class="data row3 col8" >0.001194</td>
#     </tr>
#     <tr>
#       <th id="T_81be6_level0_row4" class="row_heading level0 row4" >Hipertension</th>
#       <td id="T_81be6_row4_col0" class="data row4 col0" >-0.006441</td>
#       <td id="T_81be6_row4_col1" cl
